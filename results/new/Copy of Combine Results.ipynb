# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
! ls /content/drive/My\ Drive/Colab\ Notebooks/BTechProject_Venkatesh/results/new
# Out:
#  Abstract_KMEANS_glove_pmeans5_K350_R30000_F250_model_new_results.csv
#  Abstract_KMEANS_use_use_K350_R30000_F512_model_new_results.csv
# 'Copy of Combine Results.ipynb'

# %%
file_list = [ "Abstract_KMEANS_glove_pmeans5_K350_R30000_F250_model_new_results.csv",
              "Abstract_KMEANS_use_use_K350_R30000_F512_model_new_results.csv",
             ]

# %%
file_list = ["/content/drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/new"+f for f in file_list]

# %%
import pandas as pd

# %%
df1 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/new/Abstract_KMEANS_use_use_K350_R30000_F512_model_new_results.csv")
df2 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/new/Abstract_KMEANS_glove_pmeans5_K350_R30000_F250_model_new_results.csv")
# df3 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/KMEANS_glove_normalmean_K350_R30000_F50_T2_results.csv")
# df4 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/KMEANS_ftt_pmeans5_K350_R30000_F1500_T2_results.csv")
# df5 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/KMEANS_w2v_pmeans5_K350_R30000_F500_T2_results.csv")
# df6 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/KMEANS_glove_pmeans5_K350_R30000_F250_T2_results.csv")

# %%
df1["embedding"] = "use"
df1["sent_emb"] = "use"
df2["embedding"] = "glove"
df2["sent_emb"] = "pmean"
# df3["embedding"] = "glove"
# df3["sent_emb"] = "normalmean"
# df4["embedding"] = "fasttext"
# df4["sent_emb"] = "pmean"
# df5["embedding"] = "word2vec"
# df5["sent_emb"] = "pmean"
# df6["embedding"] = "glove"
# df6["sent_emb"] = "pmean"

# %%
df1
# Out:
#    Unnamed: 0                                 id  ... embedding sent_emb
# 0           0  http://arxiv.org/abs/1611.01962v1  ...       use      use
# 1           1   http://arxiv.org/abs/1309.6589v3  ...       use      use
#
# [2 rows x 26 columns]

# %%
combined_resultdf = pd.concat([df1,df2,])

# %%
combined_resultdf
# Out:
#    Unnamed: 0                                 id  ...      Rank_4_Topic Rank_5_Topic
# 0           0  http://arxiv.org/abs/1611.01962v1  ...               NaN          NaN
# 1           1   http://arxiv.org/abs/1309.6589v3  ...               NaN          NaN
# 0           0  http://arxiv.org/abs/1611.01962v1  ...         semantics   philosophy
# 1           1   http://arxiv.org/abs/1309.6589v3  ...  computer+science  mathematics
#
# [4 rows x 31 columns]

# %%
combined_resultdf.to_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/new/Combined_Results.csv")

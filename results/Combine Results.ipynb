# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
! ls /content/drive/My\ Drive/Colab\ Notebooks/BTechProject_Venkatesh/results
# Out:
# 'Combine Results.ipynb'
#  KMEANS_ftt_normalmean_K350_R30000_F300_T2_results.csv
#  KMEANS_ftt_pmeans5_K350_R30000_F1500_T2_results.csv
#  KMEANS_glove_normalmean_K350_R30000_F50_T2_results.csv
#  KMEANS_glove_pmeans5_K350_R30000_F250_T2_results.csv
#  KMEANS_w2v_normalmean_K350_R30000_F100_T2_results.csv
#  KMEANS_w2v_pmeans5_K350_R30000_F500_T2_results.csv

# %%
file_list = [ "KMEANS_ftt_normalmean_K350_R30000_F300_T2_results.csv",
              "KMEANS_ftt_pmeans5_K350_R30000_F1500_T2_results.csv",
              "KMEANS_glove_normalmean_K350_R30000_F50_T2_results.csv",
              "KMEANS_glove_pmeans5_K350_R30000_F250_T2_results.csv",
              "KMEANS_w2v_normalmean_K350_R30000_F100_T2_results.csv",
              "KMEANS_w2v_pmeans5_K350_R30000_F500_T2_results.csv",
             ]

# %%
file_list = ["/content/drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/"+f for f in file_list]

# %%
import pandas as pd

# %%
df1 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/KMEANS_ftt_normalmean_K350_R30000_F300_T2_results.csv")
df2 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/KMEANS_w2v_normalmean_K350_R30000_F100_T2_results.csv")
df3 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/KMEANS_glove_normalmean_K350_R30000_F50_T2_results.csv")
df4 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/KMEANS_ftt_pmeans5_K350_R30000_F1500_T2_results.csv")
df5 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/KMEANS_w2v_pmeans5_K350_R30000_F500_T2_results.csv")
df6 = pd.read_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/KMEANS_glove_pmeans5_K350_R30000_F250_T2_results.csv")

# %%
df1["embedding"] = "fasttext"
df1["sent_emb"] = "normalmean"
df2["embedding"] = "word2vec"
df2["sent_emb"] = "normalmean"
df3["embedding"] = "glove"
df3["sent_emb"] = "normalmean"
df4["embedding"] = "fasttext"
df4["sent_emb"] = "pmean"
df5["embedding"] = "word2vec"
df5["sent_emb"] = "pmean"
df6["embedding"] = "glove"
df6["sent_emb"] = "pmean"

# %%
df1
# Out:
#    Unnamed: 0       id  ... embedding    sent_emb
# 0           0  9632495  ...  fasttext  normalmean
# 1           1    10359  ...  fasttext  normalmean
#
# [2 rows x 26 columns]

# %%
combined_resultdf = pd.concat([df1,df2,df3,df4,df5,df6])

# %%
combined_resultdf
# Out:
#    Unnamed: 0       id  ... embedding    sent_emb
# 0           0  9632495  ...  fasttext  normalmean
# 1           1    10359  ...  fasttext  normalmean
# 0           0  9632495  ...  word2vec  normalmean
# 1           1    10359  ...  word2vec  normalmean
# 0           0  9632495  ...     glove  normalmean
# 1           1    10359  ...     glove  normalmean
# 0           0  9632495  ...  fasttext       pmean
# 1           1    10359  ...  fasttext       pmean
# 0           0  9632495  ...  word2vec       pmean
# 1           1    10359  ...  word2vec       pmean
# 0           0  9632495  ...     glove       pmean
# 1           1    10359  ...     glove       pmean
#
# [12 rows x 26 columns]

# %%
combined_resultdf.to_csv("./drive/My Drive/Colab Notebooks/BTechProject_Venkatesh/results/Combined_Results.csv")
